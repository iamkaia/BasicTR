# %%
import requests
from bs4 import BeautifulSoup
import time
import json

# 网站的基础 URL
BASE_URL = "https://www.hanyuguoxue.com"

# 起始的多音字列表页面
START_URL = f"{BASE_URL}/zidian/pinyin-duoyinzi"


POS_MAPPING = {
    "名词": {"ckip": "Na", "ltp": "n"},
    "动词": {"ckip": "V", "ltp": "v"},
    "形容词": {"ckip": "VH", "ltp": "a"},
    "副词": {"ckip": "D", "ltp": "d"},
    "介词": {"ckip": "P", "ltp": "p"},
    "连词": {"ckip": "C", "ltp": "c"},
    "助词": {"ckip": "T", "ltp": "u"},
    # 其他词性可以继续补充
}

raw_cixing_list = ["名词", "动词", "形容词", "副词", "介词", "连词", "助词"]

same_value = 0
def fetch_html(url):
    """发送 GET 请求并返回 HTML 内容"""
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.text
    except requests.exceptions.RequestException as e:
        print(f"请求失败: {e}")
        return None

def extract_polyphones_from_list(html):
    """从多音字列表页面提取每个字的链接和信息"""
    soup = BeautifulSoup(html, "html.parser")
    polyphone_links = []

    # 找到所有多音字的 <a> 标签
    for a_tag in soup.find_all("a", class_="han"):
        char = a_tag.find("span").text.strip()  # 提取汉字
        href = a_tag.get("href")  # 提取链接
        if href:
            full_url = BASE_URL + href  # 构造完整 URL
            polyphone_links.append({"char": char, "url": full_url})
    return polyphone_links

def parse_pinyin_and_cixing(html):
    """解析拼音和词性信息"""
    soup = BeautifulSoup(html, "html.parser")
    results = []
    tag = [0,0,0,0,0,0,0]
    flag=0
    # 提取拼音和词性部分
    test1 = soup.find("div", class_ ="zi-contents")
    if test1:
        test2 = test1.find_all("div", class_="zi-content")  # 对该元素调用 find_all()
        for test in test2:
            #print(test)
            pinyin_tags = test.find("em", class_="py")
            cixing_tags = None
            if  pinyin_tags: # 拼音部分
                pinyin_tags = pinyin_tags.text
                #print(f'pinyin_tags:{pinyin_tags}')
                cixing_tags = test.find_all("p", class_="cixing")  # 词性部分
                #print(f'cixing_tags:{cixing_tags}')

                pinyin = pinyin_tags
                cixing = None
                cixing_list = []
                for cixing in cixing_tags:
                    raw_cixing = cixing.text.strip()
                    #for index, raw_cixing in enumerate(raw_cixing_list):
                    cixing = POS_MAPPING.get(raw_cixing, {"ckip": "未知", "ltp": "未知"})
                    #print(cixing)
                    cixing_list.append(cixing)
                    
                    ##判斷有無多音字有相同詞性
                    if raw_cixing in raw_cixing_list:
                        index = raw_cixing_list.index(raw_cixing)

                        if tag[index]>=1:
                            ##已經重複了!!
                            flag=1
                            tag[index] += 1
                        else:
                            tag[index] = 1

                # 保存结果
                result = {"pinyin": pinyin}
                if cixing:
                    result["cixing"] = cixing_list
                results.append(result)

    return results, flag, tag

def crawl_polyphones(start_url):
    """爬取多音字及其详细信息"""
    polyphone_data = []
    global same_value

    # 获取起始页面的 HTML
    start_html = fetch_html(start_url)
    if not start_html:
        return []

    # 提取多音字列表及其链接
    polyphone_links = extract_polyphones_from_list(start_html)

    # 遍历每个多音字的链接
    for polyphone in polyphone_links:
        char = polyphone["char"]
        url = polyphone["url"]
        print(f"正在处理: {char} ({url})")

        # 获取具体字页面的 HTML
        detail_html = fetch_html(url)
        if not detail_html:
            continue

        # 提取详情
        details, flag, tag = parse_pinyin_and_cixing(detail_html)
        print(details)
        if flag == 1:
            same_value+=1
            print(f"same_value:{tag}")

        #details["char"] = char
        #details["url"] = url
        polyphone_data.append(details)

        # 避免过快请求，设置延迟
        time.sleep(1)

    return polyphone_data

def save_to_json(data, filename):
    """将数据保存为 JSON 文件"""
    with open(filename, "w", encoding="utf-8") as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    print(f"数据已保存到 {filename}")

# 主程序
if __name__ == "__main__":
    print("开始爬取多音字数据...")
    polyphone_data = crawl_polyphones(START_URL)
    save_to_json(polyphone_data, "polyphones.json")
    print("爬取完成！")
    print(f"詞性有重複的多音字:{same_value}")
# Out:
# 开始爬取多音字数据...
# 正在处理: 丁 (https://www.hanyuguoxue.com/zidian/zi-19969)
# [{'pinyin': 'dīng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'zhēng'}]
# 正在处理: 厂 (https://www.hanyuguoxue.com/zidian/zi-21378)
# [{'pinyin': 'chǎng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'hǎn'}, {'pinyin': 'yăn'}, {'pinyin': 'ān', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 0, 0, 0, 0, 0, 0]
# 正在处理: 卜 (https://www.hanyuguoxue.com/zidian/zi-21340)
# [{'pinyin': 'bǔ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'bo'}]
# 正在处理: 几 (https://www.hanyuguoxue.com/zidian/zi-20960)
# [{'pinyin': 'jī', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'jǐ', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[2, 1, 1, 1, 0, 0, 0]
# 正在处理: 了 (https://www.hanyuguoxue.com/zidian/zi-20102)
# [{'pinyin': 'liǎo', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'le', 'cixing': [{'ckip': 'T', 'ltp': 'u'}, {'ckip': '未知', 'ltp': '未知'}]}]
# 正在处理: 干 (https://www.hanyuguoxue.com/zidian/zi-24178)
# [{'pinyin': 'gān', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'gàn', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[4, 3, 2, 1, 0, 0, 0]
# 正在处理: 大 (https://www.hanyuguoxue.com/zidian/zi-22823)
# [{'pinyin': 'dà', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'dài', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'tài'}]
# same_value:[2, 1, 1, 1, 0, 0, 0]
# 正在处理: 与 (https://www.hanyuguoxue.com/zidian/zi-19982)
# [{'pinyin': 'yǔ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'C', 'ltp': 'c'}, {'ckip': 'T', 'ltp': 'u'}]}, {'pinyin': 'yù', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'yú'}]
# same_value:[1, 2, 0, 0, 1, 1, 1]
# 正在处理: 万 (https://www.hanyuguoxue.com/zidian/zi-19975)
# [{'pinyin': 'wàn', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'mò'}, {'pinyin': 'mǒ'}]
# 正在处理: 上 (https://www.hanyuguoxue.com/zidian/zi-19978)
# [{'pinyin': 'shàng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'shǎng'}]
# 正在处理: 个 (https://www.hanyuguoxue.com/zidian/zi-20010)
# [{'pinyin': 'gè', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'T', 'ltp': 'u'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'gě'}]
# 正在处理: 么 (https://www.hanyuguoxue.com/zidian/zi-20040)
# [{'pinyin': 'ma'}, {'pinyin': 'me', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'T', 'ltp': 'u'}]}, {'pinyin': 'yāo'}]
# 正在处理: 广 (https://www.hanyuguoxue.com/zidian/zi-24191)
# [{'pinyin': 'guǎng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'ān', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 亡 (https://www.hanyuguoxue.com/zidian/zi-20129)
# [{'pinyin': 'wáng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'wú', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 女 (https://www.hanyuguoxue.com/zidian/zi-22899)
# [{'pinyin': 'nǚ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'rǔ'}]
# 正在处理: 叉 (https://www.hanyuguoxue.com/zidian/zi-21449)
# [{'pinyin': 'chā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'chá', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'chǎ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'chà', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 4, 0, 0, 0, 0, 0]
# 正在处理: 王 (https://www.hanyuguoxue.com/zidian/zi-29579)
# [{'pinyin': 'wáng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'wàng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 夫 (https://www.hanyuguoxue.com/zidian/zi-22827)
# [{'pinyin': 'fū', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'fú', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'T', 'ltp': 'u'}]}]
# 正在处理: 扎 (https://www.hanyuguoxue.com/zidian/zi-25166)
# [{'pinyin': 'zā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'zhā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'zhá', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[0, 3, 0, 0, 0, 0, 0]
# 正在处理: 不 (https://www.hanyuguoxue.com/zidian/zi-19981)
# [{'pinyin': 'bù', 'cixing': [{'ckip': 'D', 'ltp': 'd'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'T', 'ltp': 'u'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'fǒu'}]
# 正在处理: 区 (https://www.hanyuguoxue.com/zidian/zi-21306)
# [{'pinyin': 'qū', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'ōu', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 车 (https://www.hanyuguoxue.com/zidian/zi-36710)
# [{'pinyin': 'chē', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'jū', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 0, 0, 0, 0, 0]
# 正在处理: 屯 (https://www.hanyuguoxue.com/zidian/zi-23663)
# [{'pinyin': 'tún', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'zhūn', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 1, 0, 0, 0, 0]
# 正在处理: 切 (https://www.hanyuguoxue.com/zidian/zi-20999)
# [{'pinyin': 'qiē', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'qiè', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[1, 2, 1, 0, 0, 0, 0]
# 正在处理: 瓦 (https://www.hanyuguoxue.com/zidian/zi-29926)
# [{'pinyin': 'wǎ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'wà', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 少 (https://www.hanyuguoxue.com/zidian/zi-23569)
# [{'pinyin': 'shǎo', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'shào', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[1, 1, 2, 1, 0, 0, 0]
# 正在处理: 中 (https://www.hanyuguoxue.com/zidian/zi-20013)
# [{'pinyin': 'zhōng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'zhòng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[1, 1, 2, 0, 0, 0, 0]
# 正在处理: 内 (https://www.hanyuguoxue.com/zidian/zi-20869)
# [{'pinyin': 'nèi', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'nà', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 见 (https://www.hanyuguoxue.com/zidian/zi-35265)
# [{'pinyin': 'jiàn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'T', 'ltp': 'u'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'xiàn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[1, 2, 2, 0, 0, 0, 1]
# 正在处理: 长 (https://www.hanyuguoxue.com/zidian/zi-38271)
# [{'pinyin': 'cháng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'zhǎng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 2, 1, 0, 0, 0]
# 正在处理: 什 (https://www.hanyuguoxue.com/zidian/zi-20160)
# [{'pinyin': 'shí', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'shén'}]
# 正在处理: 片 (https://www.hanyuguoxue.com/zidian/zi-29255)
# [{'pinyin': 'piàn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'piān', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 仆 (https://www.hanyuguoxue.com/zidian/zi-20166)
# [{'pinyin': 'pū', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'pú', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 化 (https://www.hanyuguoxue.com/zidian/zi-21270)
# [{'pinyin': 'huà', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'huā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 仇 (https://www.hanyuguoxue.com/zidian/zi-20167)
# [{'pinyin': 'chóu'}, {'pinyin': 'qiú', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# 正在处理: 仅 (https://www.hanyuguoxue.com/zidian/zi-20165)
# [{'pinyin': 'jǐn', 'cixing': [{'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'jìn', 'cixing': [{'ckip': 'D', 'ltp': 'd'}]}]
# same_value:[0, 0, 0, 2, 0, 0, 0]
# 正在处理: 爪 (https://www.hanyuguoxue.com/zidian/zi-29226)
# [{'pinyin': 'zhǎo', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'zhuǎ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 0, 0, 0, 0, 0]
# 正在处理: 父 (https://www.hanyuguoxue.com/zidian/zi-29238)
# [{'pinyin': 'fù', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'fǔ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[2, 2, 0, 0, 0, 0, 0]
# 正在处理: 从 (https://www.hanyuguoxue.com/zidian/zi-20174)
# [{'pinyin': 'cóng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# 正在处理: 分 (https://www.hanyuguoxue.com/zidian/zi-20998)
# [{'pinyin': 'fēn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'fèn', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[2, 2, 1, 1, 0, 0, 0]
# 正在处理: 氏 (https://www.hanyuguoxue.com/zidian/zi-27663)
# [{'pinyin': 'shì', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'zhī'}]
# 正在处理: 风 (https://www.hanyuguoxue.com/zidian/zi-39118)
# [{'pinyin': 'fēng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'fěng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'fèng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 3, 1, 0, 0, 0, 0]
# 正在处理: 勾 (https://www.hanyuguoxue.com/zidian/zi-21246)
# [{'pinyin': 'gōu', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'gòu', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 六 (https://www.hanyuguoxue.com/zidian/zi-20845)
# [{'pinyin': 'liù', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'lù', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 0, 0, 0, 0, 0, 0]
# 正在处理: 为 (https://www.hanyuguoxue.com/zidian/zi-20026)
# [{'pinyin': 'wéi', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'C', 'ltp': 'c'}, {'ckip': 'T', 'ltp': 'u'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'wèi', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'P', 'ltp': 'p'}]}]
# same_value:[1, 2, 0, 0, 2, 1, 1]
# 正在处理: 斗 (https://www.hanyuguoxue.com/zidian/zi-26007)
# [{'pinyin': 'dǒu', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'dòu', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 1, 1, 0, 0, 0]
# 正在处理: 尺 (https://www.hanyuguoxue.com/zidian/zi-23610)
# [{'pinyin': 'chǐ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'chě', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 0, 1, 0, 0, 0, 0]
# 正在处理: 予 (https://www.hanyuguoxue.com/zidian/zi-20104)
# [{'pinyin': 'yú', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'yǔ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 打 (https://www.hanyuguoxue.com/zidian/zi-25171)
# [{'pinyin': 'dǎ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'dá', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}]
# 正在处理: 正 (https://www.hanyuguoxue.com/zidian/zi-27491)
# [{'pinyin': 'zhèng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'zhēng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[2, 2, 1, 1, 0, 0, 0]
# 正在处理: 扒 (https://www.hanyuguoxue.com/zidian/zi-25170)
# [{'pinyin': 'bā'}, {'pinyin': 'pá', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'ba', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[0, 2, 0, 0, 0, 0, 0]
# 正在处理: 艾 (https://www.hanyuguoxue.com/zidian/zi-33406)
# [{'pinyin': 'ài', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'yì', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 1, 0, 0, 0, 0]
# 正在处理: 节 (https://www.hanyuguoxue.com/zidian/zi-33410)
# [{'pinyin': 'jié', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'jiē'}]
# 正在处理: 术 (https://www.hanyuguoxue.com/zidian/zi-26415)
# [{'pinyin': 'shù', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'shú'}, {'pinyin': 'zhú', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 0, 0, 0, 0, 0]
# 正在处理: 可 (https://www.hanyuguoxue.com/zidian/zi-21487)
# [{'pinyin': 'kě', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'kè'}]
# 正在处理: 石 (https://www.hanyuguoxue.com/zidian/zi-30707)
# [{'pinyin': 'shí', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'dàn', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}]
# 正在处理: 夯 (https://www.hanyuguoxue.com/zidian/zi-22831)
# [{'pinyin': 'hāng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'bèn', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}]
# 正在处理: 卡 (https://www.hanyuguoxue.com/zidian/zi-21345)
# [{'pinyin': 'qiǎ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'kǎ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[2, 1, 0, 0, 0, 0, 0]
# 正在处理: 北 (https://www.hanyuguoxue.com/zidian/zi-21271)
# [{'pinyin': 'běi', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'bèi'}]
# 正在处理: 占 (https://www.hanyuguoxue.com/zidian/zi-21344)
# [{'pinyin': 'zhān', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'zhàn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 3, 0, 0, 0, 0, 0]
# 正在处理: 且 (https://www.hanyuguoxue.com/zidian/zi-19988)
# [{'pinyin': 'qiě', 'cixing': [{'ckip': 'D', 'ltp': 'd'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'jū', 'cixing': [{'ckip': 'T', 'ltp': 'u'}]}, {'pinyin': 'iě', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}]
# 正在处理: 叶 (https://www.hanyuguoxue.com/zidian/zi-21494)
# [{'pinyin': 'yè', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'xié', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'shè', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 0, 0, 0, 0, 0]
# 正在处理: 号 (https://www.hanyuguoxue.com/zidian/zi-21495)
# [{'pinyin': 'hào', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'háo', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 只 (https://www.hanyuguoxue.com/zidian/zi-21482)
# [{'pinyin': 'zhī', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'zhǐ', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'T', 'ltp': 'u'}]}]
# 正在处理: 叨 (https://www.hanyuguoxue.com/zidian/zi-21480)
# [{'pinyin': 'tāo', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'dāo', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[0, 2, 1, 0, 0, 0, 0]
# 正在处理: 凹 (https://www.hanyuguoxue.com/zidian/zi-20985)
# [{'pinyin': 'āo', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'wā'}]
# 正在处理: 仔 (https://www.hanyuguoxue.com/zidian/zi-20180)
# [{'pinyin': 'zī', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'zǐ', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'zǎi', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 0, 1, 0, 0, 0, 0]
# 正在处理: 令 (https://www.hanyuguoxue.com/zidian/zi-20196)
# [{'pinyin': 'líng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'lǐng', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'lìng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'C', 'ltp': 'c'}]}]
# same_value:[1, 2, 1, 0, 0, 1, 0]
# 正在处理: 乐 (https://www.hanyuguoxue.com/zidian/zi-20048)
# [{'pinyin': 'lè', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'yuè', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'yào'}, {'pinyin': 'lào'}]
# same_value:[2, 2, 0, 0, 0, 0, 0]
# 正在处理: 句 (https://www.hanyuguoxue.com/zidian/zi-21477)
# [{'pinyin': 'jù', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'gōu', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'C', 'ltp': 'c'}, {'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 0, 0, 0, 1, 0]
# 正在处理: 处 (https://www.hanyuguoxue.com/zidian/zi-22788)
# [{'pinyin': 'chǔ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'chù', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# 正在处理: 冯 (https://www.hanyuguoxue.com/zidian/zi-20911)
# [{'pinyin': 'féng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'píng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 头 (https://www.hanyuguoxue.com/zidian/zi-22836)
# [{'pinyin': 'tóu', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'T', 'ltp': 'u'}]}, {'pinyin': 'tou'}]
# 正在处理: 宁 (https://www.hanyuguoxue.com/zidian/zi-23425)
# [{'pinyin': 'níng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'nìng', 'cixing': [{'ckip': 'C', 'ltp': 'c'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'zhù', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[3, 2, 1, 1, 0, 1, 0]
# 正在处理: 召 (https://www.hanyuguoxue.com/zidian/zi-21484)
# [{'pinyin': 'zhào', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'shào'}]
# 正在处理: 发 (https://www.hanyuguoxue.com/zidian/zi-21457)
# [{'pinyin': 'fā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'fà', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'fèi', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 圣 (https://www.hanyuguoxue.com/zidian/zi-22307)
# [{'pinyin': 'shèng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'kū'}]
# 正在处理: 台 (https://www.hanyuguoxue.com/zidian/zi-21488)
# [{'pinyin': 'tái', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'tāi', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[5, 0, 0, 0, 0, 0, 0]
# 正在处理: 扛 (https://www.hanyuguoxue.com/zidian/zi-25179)
# [{'pinyin': 'káng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'gāng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[0, 2, 0, 0, 0, 0, 0]
# 正在处理: 扫 (https://www.hanyuguoxue.com/zidian/zi-25195)
# [{'pinyin': 'sǎo', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'sào'}]
# 正在处理: 地 (https://www.hanyuguoxue.com/zidian/zi-22320)
# [{'pinyin': 'dì', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'de'}]
# 正在处理: 场 (https://www.hanyuguoxue.com/zidian/zi-22330)
# [{'pinyin': 'cháng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'chǎng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'chang'}]
# same_value:[2, 0, 0, 0, 0, 0, 0]
# 正在处理: 共 (https://www.hanyuguoxue.com/zidian/zi-20849)
# [{'pinyin': 'gòng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'gōng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'gǒng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[2, 3, 0, 1, 1, 1, 0]
# 正在处理: 朴 (https://www.hanyuguoxue.com/zidian/zi-26420)
# [{'pinyin': 'pǔ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'pò', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'pō'}, {'pinyin': 'piáo', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[3, 1, 2, 0, 0, 0, 0]
# 正在处理: 过 (https://www.hanyuguoxue.com/zidian/zi-36807)
# [{'pinyin': 'guò', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'guo'}, {'pinyin': 'guō', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 压 (https://www.hanyuguoxue.com/zidian/zi-21387)
# [{'pinyin': 'yā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'yà'}]
# 正在处理: 有 (https://www.hanyuguoxue.com/zidian/zi-26377)
# [{'pinyin': 'yǒu', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'yòu'}]
# 正在处理: 夸 (https://www.hanyuguoxue.com/zidian/zi-22840)
# [{'pinyin': 'kuā', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}]}]
# 正在处理: 夹 (https://www.hanyuguoxue.com/zidian/zi-22841)
# [{'pinyin': 'jiā', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'jiá', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'gā'}]
# same_value:[1, 1, 2, 0, 0, 0, 0]
# 正在处理: 邪 (https://www.hanyuguoxue.com/zidian/zi-37034)
# [{'pinyin': 'xié', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'yé'}]
# 正在处理: 划 (https://www.hanyuguoxue.com/zidian/zi-21010)
# [{'pinyin': 'huá', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'huà', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'huai'}]
# same_value:[2, 3, 0, 1, 0, 0, 0]
# 正在处理: 当 (https://www.hanyuguoxue.com/zidian/zi-24403)
# [{'pinyin': 'dāng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'dàng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'dang'}]
# same_value:[2, 2, 1, 0, 1, 1, 0]
# 正在处理: 吁 (https://www.hanyuguoxue.com/zidian/zi-21505)
# [{'pinyin': 'xū', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'yù', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'yū', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[0, 2, 0, 0, 0, 0, 0]
# 正在处理: 吐 (https://www.hanyuguoxue.com/zidian/zi-21520)
# [{'pinyin': 'tǔ', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'tù', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 吓 (https://www.hanyuguoxue.com/zidian/zi-21523)
# [{'pinyin': 'xià', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'hè', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[0, 2, 0, 0, 0, 0, 0]
# 正在处理: 曲 (https://www.hanyuguoxue.com/zidian/zi-26354)
# [{'pinyin': 'qū', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'qǔ', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}]
# same_value:[3, 1, 1, 0, 0, 0, 0]
# 正在处理: 同 (https://www.hanyuguoxue.com/zidian/zi-21516)
# [{'pinyin': 'tóng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'tòng'}]
# 正在处理: 吗 (https://www.hanyuguoxue.com/zidian/zi-21527)
# [{'pinyin': 'má', 'cixing': [{'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'mǎ'}, {'pinyin': 'ma', 'cixing': [{'ckip': 'T', 'ltp': 'u'}]}]
# 正在处理: 岂 (https://www.hanyuguoxue.com/zidian/zi-23682)
# [{'pinyin': 'qǐ', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'kǎi'}]
# 正在处理: 朱 (https://www.hanyuguoxue.com/zidian/zi-26417)
# [{'pinyin': 'zhū', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'shú'}]
# same_value:[2, 0, 1, 0, 0, 0, 0]
# 正在处理: 传 (https://www.hanyuguoxue.com/zidian/zi-20256)
# [{'pinyin': 'chuán', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'zhuàn', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 休 (https://www.hanyuguoxue.com/zidian/zi-20241)
# [{'pinyin': 'xiū', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'xǔ'}]
# 正在处理: 任 (https://www.hanyuguoxue.com/zidian/zi-20219)
# [{'pinyin': 'rèn', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'C', 'ltp': 'c'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'rén', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}]
# same_value:[2, 1, 1, 0, 0, 1, 0]
# 正在处理: 价 (https://www.hanyuguoxue.com/zidian/zi-20215)
# [{'pinyin': 'jià', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'jiè', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'jie', 'cixing': [{'ckip': 'T', 'ltp': 'u'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 1]
# 正在处理: 份 (https://www.hanyuguoxue.com/zidian/zi-20221)
# [{'pinyin': 'fèn', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'bīn'}]
# 正在处理: 华 (https://www.hanyuguoxue.com/zidian/zi-21326)
# [{'pinyin': 'huá', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'huà', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'huā', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[3, 1, 1, 0, 0, 0, 0]
# 正在处理: 仰 (https://www.hanyuguoxue.com/zidian/zi-20208)
# [{'pinyin': 'yǎng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'áng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}]
# 正在处理: 血 (https://www.hanyuguoxue.com/zidian/zi-34880)
# [{'pinyin': 'xuè', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'xiě', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 0, 0, 0, 0]
# 正在处理: 似 (https://www.hanyuguoxue.com/zidian/zi-20284)
# [{'pinyin': 'sì', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'P', 'ltp': 'p'}]}, {'pinyin': 'shì', 'cixing': [{'ckip': 'T', 'ltp': 'u'}]}]
# 正在处理: 行 (https://www.hanyuguoxue.com/zidian/zi-34892)
# [{'pinyin': 'háng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'xíng'}, {'pinyin': 'hàng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}]
# 正在处理: 会 (https://www.hanyuguoxue.com/zidian/zi-20250)
# [{'pinyin': 'huì', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'kuài', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 2, 0, 1, 0, 1, 0]
# 正在处理: 合 (https://www.hanyuguoxue.com/zidian/zi-21512)
# [{'pinyin': 'hé', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'P', 'ltp': 'p'}, {'ckip': '未知', 'ltp': '未知'}]}, {'pinyin': 'gě', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# same_value:[2, 1, 1, 1, 1, 0, 0]
# 正在处理: 创 (https://www.hanyuguoxue.com/zidian/zi-21019)
# [{'pinyin': 'chuàng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'chuāng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}]
# same_value:[1, 2, 0, 0, 0, 0, 0]
# 正在处理: 肋 (https://www.hanyuguoxue.com/zidian/zi-32907)
# [{'pinyin': 'lèi', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'lē'}]
# 正在处理: 各 (https://www.hanyuguoxue.com/zidian/zi-21508)
# [{'pinyin': 'gè', 'cixing': [{'ckip': '未知', 'ltp': '未知'}, {'ckip': 'D', 'ltp': 'd'}]}, {'pinyin': 'gě', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}]}]
# 正在处理: 冲 (https://www.hanyuguoxue.com/zidian/zi-20914)
# [{'pinyin': 'chōng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'chòng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'P', 'ltp': 'p'}]}]
# same_value:[1, 3, 2, 0, 1, 0, 0]
# 正在处理: 庄 (https://www.hanyuguoxue.com/zidian/zi-24196)
# [{'pinyin': 'zhuāng', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': '未知', 'ltp': '未知'}, {'ckip': 'V', 'ltp': 'v'}]}, {'pinyin': 'péng'}]
# 正在处理: 齐 (https://www.hanyuguoxue.com/zidian/zi-40784)
# [{'pinyin': 'qí', 'cixing': [{'ckip': 'VH', 'ltp': 'a'}, {'ckip': 'V', 'ltp': 'v'}, {'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'P', 'ltp': 'p'}]}, {'pinyin': 'jì', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}, {'pinyin': 'zī'}, {'pinyin': 'zhāi'}]
# same_value:[2, 1, 1, 1, 1, 0, 0]
# 正在处理: 羊 (https://www.hanyuguoxue.com/zidian/zi-32650)
# [{'pinyin': 'yáng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}, {'ckip': 'VH', 'ltp': 'a'}]}, {'pinyin': 'xiáng'}]
# 正在处理: 并 (https://www.hanyuguoxue.com/zidian/zi-24182)
# [{'pinyin': 'bìng', 'cixing': [{'ckip': 'V', 'ltp': 'v'}, {'ckip': 'D', 'ltp': 'd'}, {'ckip': 'C', 'ltp': 'c'}]}, {'pinyin': 'bīng', 'cixing': [{'ckip': 'Na', 'ltp': 'n'}]}]
# 数据已保存到 polyphones.json
# 爬取完成！
# 詞性有重複的多音字:69
